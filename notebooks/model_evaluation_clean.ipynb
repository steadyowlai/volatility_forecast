# %% [markdown]
# # Model Evaluation (Clean)
#
# Time-aware setup for linear, random forest, XGBoost, and LightGBM with clear train/val/test splits.

# %% [markdown]
# ## 1. Environment Setup

# %%
# Configure display options and plotting defaults
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", 100)
pd.set_option("display.width", 120)
